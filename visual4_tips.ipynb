# %% [markdown]
# # Tips

# %% [markdown]
# ### Introduction:
#
# This exercise was created based on the tutorial and documentation from [Seaborn](https://stanford.edu/~mwaskom/software/seaborn/index.html)
# The dataset being used is tips from Seaborn.
#
# ### Step 1. Import the necessary libraries:

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/Visualization/Tips/tips.csv).

# %% [markdown]
# ### Step 3. Assign it to a variable called tips

# %%
tips = pd.read_csv("tips_data.csv")
tips.head(3)
# Out:
#    Unnamed: 0  total_bill   tip     sex smoker  day    time  size
# 0           0       16.99  1.01  Female     No  Sun  Dinner     2
# 1           1       10.34  1.66    Male     No  Sun  Dinner     3
# 2           2       21.01  3.50    Male     No  Sun  Dinner     3

# %% [markdown]
# ### Step 4. Delete the Unnamed 0 column

# %%
tips1 = tips.drop("Unnamed: 0", axis = 1, inplace = True)
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# ### Step 5. Plot the total_bill column histogram

# %%
plt.figure(figsize=(16,6))
sns.distplot(a = tips['total_bill'],kde = False, bins = 100)

# %% [markdown]
# ### Step 6. Create a scatter plot presenting the relationship between total_bill and tip

# %%
plt.figure(figsize = (16,6))
sns.scatterplot(x = tips['total_bill'],y = tips['tip'])

# %% [markdown]
# ### Step 7.  Create one image with the relationship of total_bill, tip and size.
# #### Hint: It is just one function.

# %%
plt.figure(figsize = (16,6))
sns.scatterplot(x = tips['total_bill'],y = tips['tip'],style = tips['size'])

# %% [markdown]
# ### Step 8. Present the relationship between days and total_bill value

# %%
plt.figure(figsize = (16,6))
sns.scatterplot(x = tips['day'], y = tips['total_bill'],x_bins = 5,y_bins = 100)

# %% [markdown]
# ### Step 9. Create a scatter plot with the day as the y-axis and tip as the x-axis, differ the dots by sex

# %%
plt.figure(figsize = (16,6))
sns.scatterplot(x = tips['tip'], y = tips['day'],hue = tips['sex'])

# %% [markdown]
# ### Step 10.  Create a box plot presenting the total_bill per day differetiation the time (Dinner or Lunch)

# %%
sns.boxplot(x = tips['time'], y = tips['total_bill'])

# %% [markdown]
# ### Step 11. Create two histograms of the tip value based for Dinner and Lunch. They must be side by side.

# %%
def Din(x):
    if(x == 'Dinner'):
        return "1"
    else:
        return np.nan
tips['Dinner'] = tips['time'].apply(Din)


def Lun(x):
    if(x == 'Lunch'):
        return "1"
    else:
        return np.nan
tips['Lunch'] = tips['time'].apply(Lun)

# %%
sns.distplot(a = tips['Dinner'],kde = False,bins = 100)

# %%
plt.figure(figsize = (16,6))
sns.distplot(a = tips['tip'],kde = False,bins = 100)
#kde = False,bins = 100

# %% [markdown]
# ### Step 12. Create two scatterplots graphs, one for Male and another for Female, presenting the total_bill value and tip relationship, differing by smoker or no smoker
# ### They must be side by side.

# %%
def sexF(x):
    if(x == 'Female'):
        return "Female"
    else:
        return 0
tips['Female'] = tips['sex'].apply(sexF)

# %%
def sexM(x):
    if(x == 'Male'):
        return "Male"
    else:
        return 0
tips['Male'] = tips['sex'].apply(sexM)

# %%
plt.figure(figsize = (6,6))
sns.scatterplot(x = tips['total_bill'],y = tips['tip'],hue = tips['smoker'],style = tips['Male'])

plt.figure(figsize = (6,6))
sns.scatterplot(x = tips['total_bill'],y = tips['tip'],hue = tips['smoker'],style = tips['Female'])

# %% [markdown]
# ### BONUS: Create your own question and answer it using a graph.

# %%
plt.figure(figsize=(16,6))
sns.scatterplot(x = tips['day'],y = tips['time'],hue = tips['smoker'],style = tips['sex'])
